# %%
#pwd
# Out:
# '/content'

# %%
""" the following code is for if you are working on google colab
#import os, pathlib

target = pathlib.Path("/content/drive/MyDrive/NCAI/KPITB/Lectures/KPITB Swat AI Lectures/W7/dataset/Segmentation")
os.chdir(target)
print("Now in:", pathlib.Path.cwd())"""
# Out:
# Now in: /content/drive/MyDrive/NCAI/KPITB/Lectures/KPITB Swat AI Lectures/W7/dataset/Segmentation

# %%
#pwd
# Out:
# '/content/drive/MyDrive/NCAI/KPITB/Lectures/KPITB Swat AI Lectures/W7/dataset/Segmentation'

# %%
#!pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8s model
model = YOLO('yolov8s-seg.pt')

# Train the model
results = model.train(
    data= "C:\\Users\\Saif Ullah\\KPITB-Course\\week 7\\Fruit_Segmetation.yolov8\\data.yaml",
    epochs=20,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.21  Python-3.12.12 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1050 Ti with Max-Q Design, 4096MiB)
# ...

# %%
# Segmentation inference (single image)
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source="C:\Users\Saif Ullah\KPITB-Course\week 7\Fruit_Segmetation.yolov8\test_img.jpg" save=True
# Out:
# Ultralytics 8.4.21  Python-3.12.12 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1050 Ti with Max-Q Design, 4096MiB)
# YOLOv8s-seg summary (fused): 86 layers, 11,782,696 parameters, 0 gradients, 39.9 GFLOPs
#
# image 1/1 C:\Users\Saif Ullah\KPITB-Course\week 7\Fruit_Segmetation.yolov8\test_img.jpg: 352x640 4 kiwis, 3 mangoess, 4 orangess, 79.4ms
# Speed: 2.1ms preprocess, 79.4ms inference, 21.1ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to C:\Users\Saif Ullah\KPITB-Course\week 7\runs\segment\predict6
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# 1. Set the path to your image directly
img_path = r"C:\Users\Saif Ullah\KPITB-Course\week 7\Fruit_Segmetation.yolov8\test_img.jpg"

# 2. Load the best weights from your recent training
model = YOLO('runs/segment/train/weights/best.pt')

# 3. Run inference
results = model.predict(source=img_path, save=True, conf=0.25)

# 4. Visualize the result
res_plotted = results[0].plot()

plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(f'Prediction on: {img_path}')
plt.show()
# Out:
# image 1/1 C:\Users\Saif Ullah\KPITB-Course\week 7\Fruit_Segmetation.yolov8\test_img.jpg: 352x640 4 kiwis, 3 mangoess, 4 orangess, 27.5ms
# Speed: 1.6ms preprocess, 27.5ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to C:\Users\Saif Ullah\KPITB-Course\week 7\runs\segment\predict7

# %%
import matplotlib
matplotlib.use('TkAgg')  # Force a display backend
import matplotlib.pyplot as plt
