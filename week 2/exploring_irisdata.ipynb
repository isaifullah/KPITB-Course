# %% [markdown]
# # working on on iris dataset for Exploratory data analysis

# %%
# import Libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# !pip install ydata_profiling
# Out:
# ^C

# %%
# now, we will try ydata_profilling to see the overivew of the dataset.
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Iris Dataset Profiling Report", explorative=True)
profile.to_file("iris_dataset_profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # now, we will try ydata_profilling to see the overivew of the dataset.
# ----> 2 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(df, title="Iris Dataset Profiling Report", explorative=True)
#       4 profile.to_file("iris_dataset_profiling_report.html")
#
# ModuleNotFoundError: No module named 'ydata_profiling'
